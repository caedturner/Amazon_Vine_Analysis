# %%
import pandas as pd

# %%
vine_df = pd.read_csv("/Users/caed/Desktop/Data_Repository/Amazon_Vine_Analysis/vine_table.csv")
vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 0        R8MEA6IGAHO0B            5              0            0    N
# 1       R31LOQ8JGLPRLK            5              0            1    N
# 2       R2Y0MM9YE6OP3P            5              0            0    N
# 3        RRB9C05HDOD4O            4              0            0    N
# 4       R26I2RI1GFV8QG            2              0            0    N
# ...                ...          ...            ...          ...  ...
# 104970  R2CDRVDUKB5Z9P            5             23           27    N
# 104971   R1DVLTZFXXOX9            5             10           11    N
# 104972  R1GHKKZMHAHQC1            5             13           13    N
# 104973  R227G6T5B26DVC            5             58           61    N
# 104974   R44WS2RSQQ0HR            4             37           38    N
#
#        verified_purchase
# 0                      Y
# 1                      Y
# 2                      Y
# 3                      Y
# ...

# %%
vine_df.dtypes
# Out:
# review_id            object
# star_rating           int64
# helpful_votes         int64
# total_votes           int64
# vine                 object
# verified_purchase    object
# dtype: object

# %%
filtered_df = vine_df[vine_df['total_votes'] >= 20]
filtered_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 9        RBEMQ29WJBHYG            5            164          168    N
# 83      R2JK5Y8D5MXAGP            1              5          121    N
# 195     R13W3EMIUV120L            4            288          294    N
# 217     R30TJ8POYNVCRE            5             15           21    N
# 296     R1H5Y9Z2DHRNVO            1              4           95    N
# ...                ...          ...            ...          ...  ...
# 104967  R2Y5CQEWBI145K            2             48           57    N
# 104968   RWYG4S02ONH29            5             85           95    N
# 104970  R2CDRVDUKB5Z9P            5             23           27    N
# 104973  R227G6T5B26DVC            5             58           61    N
# 104974   R44WS2RSQQ0HR            4             37           38    N
#
#        verified_purchase
# 9                      Y
# 83                     Y
# 195                    Y
# 217                    N
# ...

# %%
helpful_div_total_df = filtered_df['helpful_votes']/filtered_df['total_votes']
helpful_div_total_df.head()
# Out:
# 9      0.976190
# 83     0.041322
# 195    0.979592
# 217    0.714286
# 296    0.042105
# dtype: float64

# %%
filtered_df['helpful_vote_ratio'] = helpful_div_total_df
filtered_df
# Out:
# /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 9        RBEMQ29WJBHYG            5            164          168    N
# 83      R2JK5Y8D5MXAGP            1              5          121    N
# 195     R13W3EMIUV120L            4            288          294    N
# 217     R30TJ8POYNVCRE            5             15           21    N
# 296     R1H5Y9Z2DHRNVO            1              4           95    N
# ...                ...          ...            ...          ...  ...
# ...

# %%
filtered_df = filtered_df.loc[filtered_df["helpful_vote_ratio"]>0.5]#filtered_df = filtered_df[(filtered_df['helpful_vote_ratio'] >= 0.50)]
filtered_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 9        RBEMQ29WJBHYG            5            164          168    N
# 195     R13W3EMIUV120L            4            288          294    N
# 217     R30TJ8POYNVCRE            5             15           21    N
# 530     R1LK03P7BCJEJD            1             31           35    N
# 625      RBXUICKGHL685            1             48           52    N
# ...                ...          ...            ...          ...  ...
# 104967  R2Y5CQEWBI145K            2             48           57    N
# 104968   RWYG4S02ONH29            5             85           95    N
# 104970  R2CDRVDUKB5Z9P            5             23           27    N
# 104973  R227G6T5B26DVC            5             58           61    N
# 104974   R44WS2RSQQ0HR            4             37           38    N
#
#        verified_purchase  helpful_vote_ratio
# 9                      Y            0.976190
# 195                    Y            0.979592
# ...

# %%
paid_df = filtered_df.loc[filtered_df['vine'] == 'Y']
paid_df.head(10)
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 41600  R3BOQTLUU3Y4L8            4             42           55    Y
# 42191   RWF03LXVXC22A            3            396          445    Y
# 42845   REPU28WG1VZUE            5            242          281    Y
# 43054  R1D6REC9HPJVQY            4             31           41    Y
#
#       verified_purchase  helpful_vote_ratio
# 41600                 N            0.763636
# 42191                 N            0.889888
# 42845                 N            0.861210
# 43054                 N            0.756098

# %%
unpaid_df = filtered_df.loc[filtered_df['vine'] == 'N']
unpaid_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 9        RBEMQ29WJBHYG            5            164          168    N
# 195     R13W3EMIUV120L            4            288          294    N
# 217     R30TJ8POYNVCRE            5             15           21    N
# 530     R1LK03P7BCJEJD            1             31           35    N
# 625      RBXUICKGHL685            1             48           52    N
# ...                ...          ...            ...          ...  ...
# 104967  R2Y5CQEWBI145K            2             48           57    N
# 104968   RWYG4S02ONH29            5             85           95    N
# 104970  R2CDRVDUKB5Z9P            5             23           27    N
# 104973  R227G6T5B26DVC            5             58           61    N
# 104974   R44WS2RSQQ0HR            4             37           38    N
#
#        verified_purchase  helpful_vote_ratio
# 9                      Y            0.976190
# 195                    Y            0.979592
# ...

# %%
reviews_count = len(vine_df['review_id'])

reviews_count
# Out:
# 104975

# %%
five_star_df = vine_df.loc[vine_df['star_rating'] == 5]
five_star_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 0        R8MEA6IGAHO0B            5              0            0    N
# 1       R31LOQ8JGLPRLK            5              0            1    N
# 2       R2Y0MM9YE6OP3P            5              0            0    N
# 7       R3RRXU2R23NMQ9            5              0            0    N
# 9        RBEMQ29WJBHYG            5            164          168    N
# ...                ...          ...            ...          ...  ...
# 104968   RWYG4S02ONH29            5             85           95    N
# 104970  R2CDRVDUKB5Z9P            5             23           27    N
# 104971   R1DVLTZFXXOX9            5             10           11    N
# 104972  R1GHKKZMHAHQC1            5             13           13    N
# 104973  R227G6T5B26DVC            5             58           61    N
#
#        verified_purchase
# 0                      Y
# 1                      Y
# 2                      Y
# 7                      Y
# ...

# %%
five_star_df_count = len(five_star_df)
five_star_df_count
# Out:
# 52255

# %%
percentage_five_star = five_star_df_count/reviews_count
percentage_five_star
# Out:
# 0.49778518694927365

# %%
five_star_paid = paid_df.loc[paid_df['star_rating'] == 5]
five_star_paid_count = len(five_star_paid)
five_star_paid_count
# Out:
# 1

# %%
five_star_unpaid = unpaid_df.loc[unpaid_df['star_rating'] == 5]
five_star_unpaid_count = len(five_star_unpaid)
five_star_unpaid_count
# Out:
# 525

# %%
paid_count = len(paid_df)
paid_count
# Out:
# 4

# %%
unpaid_count = len(unpaid_df)
unpaid_count
# Out:
# 1062

# %%
percentage_five_star_paid = five_star_paid_count/paid_count
percentage_five_star_paid
# Out:
# 0.25

# %%
percentage_five_star_unpaid = five_star_unpaid_count/unpaid_count
percentage_five_star_unpaid
# Out:
# 0.4943502824858757
